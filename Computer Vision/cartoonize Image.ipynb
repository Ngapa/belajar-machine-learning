# %% [markdown]
# <a href="https://colab.research.google.com/github/Ngapa/belajar-machine-learning/blob/main/Computer%20Vision/cartoonize%20Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow
img_clr = cv2.imread('1.jpg')
numBilateralFilters = 30

for _ in range(numBilateralFilters):
  img_clr = cv2.bilateralFilter(imgClr, 9, 9, 7)

img_gray = cv2.cvtColor(img_clr, cv2.COLOR_RGB2GRAY)
img_blur = cv2.medianBlur(img_gray, 3)
img_edge = cv2.adaptiveThreshold(img_blur, 255,
                                          cv2.ADAPTIVE_THRESH_MEAN_C,
                                          cv2.THRESH_BINARY, 9, 2)
img_edge = cv2.cvtColor(img_edge, cv2.COLOR_GRAY2RGB)
cv2_imshow(img_clr)
cv2_imshow(img_edge)

res = cv2.bitwise_and(img_clr, img_edge)

cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F5285D75BD0>
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F5285D75490>
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F5285D7C710>
